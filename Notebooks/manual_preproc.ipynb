# %%
import pandas as pd
import numpy as np
import re

# %%
dataset_1 = pd.read_csv('../Datasets/Emotion_final.csv')
dataset_2 = pd.read_csv('../Datasets/Text_emotion.csv')

# %%
dataset_2 = dataset_2[['content', 'sentiment']]

# %%
dataset_2.rename(columns={'content': 'Text',
                        'sentiment': 'Emotion'},
                        inplace=True, errors='raise')

# %%
dataset = pd.concat([dataset_1, dataset_2])

# %%
dataset[dataset['Emotion'] == "happiness"] = "happy"

# %%
dataset = dataset[dataset.Emotion != 'empty']

# %%
dataset.head(1)
# Out:
#                       Text  Emotion
# 0  i didnt feel humiliated  sadness

# %%
dataset.shape
# Out:
# (60632, 2)

# %% [markdown]
# # Preprocessing techniques for textual data

# %%
text = dataset['Text']
for row in text[:10]:
    print(row)
# Out:
# i didnt feel humiliated
# i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake
# im grabbing a minute to post i feel greedy wrong
# i am ever feeling nostalgic about the fireplace i will know that it is still on the property
# i am feeling grouchy
# ive been feeling a little burdened lately wasnt sure why that was
# ive been taking or milligrams or times recommended amount and ive fallen asleep a lot faster but i also feel like so funny
# i feel as confused about life as a teenager or as jaded as a year old man
# i have been with petronas for years i feel that petronas has performed well and made a huge profit
# i feel romantic too

# %%
for index, row in dataset.iterrows():
    row['Text'] = row['Text'].lower()

# %% [markdown]
# Remove punctuation

# %%
import string
translator = str.maketrans('', '', string.punctuation)

for index, row in dataset.iterrows():
    row['Text'] = row['Text'].translate(translator)

# %% [markdown]
# Replace contraction

# %%
contraction_patterns = [ (r'won\'t', 'will not'), (r'can\'t', 'cannot'), (r'i\'m', 'i am'), (r'ain\'t', 'is not'), (r'(\w+)\'ll', '\g<1> will'), (r'(\w+)n\'t', '\g<1> not'),
                         (r'(\w+)\'ve', '\g<1> have'), (r'(\w+)\'s', '\g<1> is'), (r'(\w+)\'re', '\g<1> are'), (r'(\w+)\'d', '\g<1> would'), (r'&', 'and'), (r'dammit', 'damn it'), (r'dont', 'do not'), (r'wont', 'will not') ]
def replaceContraction(text):
    patterns = [(re.compile(regex), repl) for (regex, repl) in contraction_patterns]
    for (pattern, repl) in patterns:
        (text, count) = re.subn(pattern, repl, text)
    return text

# %%
for index, row in dataset.iterrows():
    row['Text'] = replaceContraction(row['Text'])

# %% [markdown]
# Replace negations

# %%
import nltk
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

def replace(word, pos=None):
    """ Creates a set of all antonyms for the word and if there is only one antonym, it returns it """
    antonyms = set()
    for syn in wordnet.synsets(word, pos=pos):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                antonyms.add(antonym.name())
    if len(antonyms) == 1:
        return antonyms.pop()
    else:
        return None

def replaceNegations(text):
    """ Finds "not" and antonym for the next word and if found, replaces not and the next word with the antonym """
    i, l = 0, len(text)
    words = []
    while i < l:
        word = text[i]
        if word == 'not' and i+1 < l:
            ant = replace(text[i+1])
            if ant:
                words.append(ant)
                i += 2
                continue
        words.append(word)
        i += 1
    return words

def tokenize_negation(text):
    tokens = nltk.word_tokenize(text)
    tokens = replaceNegations(tokens)
    text = " ".join(tokens)
    return text
# Out:
# [nltk_data] Downloading package punkt to /home/subut0n/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/subut0n/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/subut0n/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
for index, row in dataset.iterrows():
    row['Text'] = tokenize_negation(row['Text'])

# %% [markdown]
# Replace stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stoplist = stopwords.words('english')

def tokenize_stopwords(text):
    finalTokens = []
    tokens = nltk.word_tokenize(text)
    for w in tokens:
        if (w not in stoplist):
            finalTokens.append(w)
    text = " ".join(finalTokens)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/subut0n/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for index, row in dataset.iterrows():
    row['Text'] = tokenize_stopwords(row['Text'])

# %% [markdown]
# Lemmatize / Stemme

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer() #set stemmer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() # set lemmatizer

def tokenize_lemma(text):
    finalTokens = []
    tokens = nltk.word_tokenize(text)
    for w in tokens:
        finalTokens.append(lemmatizer.lemmatize(w)) # change this to lemmatizer.lemmatize(w) for Lemmatizing
    text = " ".join(finalTokens)
    return text

# %%
for index, row in dataset.iterrows():
    row['Text'] = tokenize_lemma(row['Text'])

# %%
dataset['Text']
# Out:
# 0                                    didnt feel humiliated
# 1        go feeling hopeless damned hopeful around some...
# 2                im grabbing minute post feel greedy wrong
# 3        ever feeling nostalgic fireplace know still pr...
# 4                                          feeling grouchy
#                                ...
# 39995                                      johnlloydtaylor
# 39996                                happy mother day love
# 39997    happy mother day mommy woman man long youre mo...
# 39998                                                happy
# 39999    mopedronin bullet train tokyo gf visiting japa...
# Name: Text, Length: 60632, dtype: object

# %%
dataset.Emotion.value_counts()
# Out:
# happy         12238
# sadness       11430
# neutral        8638
# worry          8459
# love           5483
# anger          3103
# surprise       3066
# fear           2652
# fun            1776
# relief         1526
# hate           1323
# enthusiasm      759
# boredom         179
# Name: Emotion, dtype: int64

# %%
dataset.shape
# Out:
# (60632, 2)

# %%
from sklearn.model_selection import train_test_split
train_dataset, test_dataset = train_test_split(dataset, test_size=0.2)

# %%
train_dataset.shape
# Out:
# (48505, 2)

# %%
from collections import Counter

def counter_word(text):
    count = Counter()
    for i in text.values:
        for word in i.split():
            count[word] +=1
    return count

# %%
text = train_dataset.Text
counter = counter_word(text)

# %%
len(counter)
# Out:
# 46031

# %%
counter
# Out:
# Counter({'smoker': 4,
#          'year': 630,
#          'quit': 26,
#          'week': 717,
#          'ago': 173,
#          'right': 858,
#          'finished': 144,
#          'book': 278,
#          'cant': 1375,
#          'believe': 223,
#          'free': 245,
#          'feel': 12226,
#          'knew': 142,
#          'terrified': 77,
#          'life': 884,
#          'without': 367,
#          'cigarette': 12,
#          'lishreece': 1,
#          'perfect': 140,
#          'moment': 256,
#          'broke': 146,
#          'one': 1718,
#          'tile': 2,
#          'floor': 41,
#          'hallway': 3,
#          'lose': 79,
#          'happy': 5187,
#          'mother': 868,
#          'day': 2857,
#          'balmain': 2,
#          'knockoff': 2,
#          'bebe': 3,
#          'make': 1376,
#          'sadi': 2,
#          'want': 1533,
#          'real': 216,
#          'dealthese': 1,
#          'shoe': 71,
#          'look': 703,
#          'cheapy': 2,
#          'teared': 1,
#          'already': 403,
#          'felt': 363,
#          'stressed': 159,
#          'havent': 250,
#          'telling': 68,
#          'anyone': 269,
#          'showing': 44,
#          'much': 1088,
#          'school': 474,
#          'jordanknight': 13,
#          'bed': 422,
#          'finger': 95,
#          'toe': 38,
#          'everything': 361,
#          'crossed': 29,
#          'u': 1308,
#          'pick': 71,
#          'melol': 2,
#          'hope': 690,
#          'ur': 260,
#          'well': 996,
#          'got': 1526,
#          'back': 1364,
#          'safepoor': 1,
#          'jon': 27,
#          'xx': 109,
#          'wouldnt': 104,
#          'say': 782,
#          'suffer': 25,
#          'social': 48,
#          'discomfort': 5,
#          'ive': 985,
#          'found': 274,
#          'place': 303,
#          'comfortable': 99,
#          'even': 917,
#          'people': 1053,
#          'accepted': 132,
#          'way': 911,
#          'masterluke103': 1,
#          'oh': 709,
#          'lady': 106,
#          'lol': 870,
#          'morganedgar1307': 1,
#          'ugh': 183,
#          'yeeet': 1,
#          'like': 4246,
#          'ill': 706,
#          'keep': 410,
#          'trying': 434,
#          'feeling': 5717,
#          'pleasant': 58,
#          'know': 1591,
#          'talk': 281,
#          'ppl': 53,
#          'ladder': 2,
#          'vain': 65,
#          'amp': 748,
#          'shallow': 11,
#          'bla': 4,
#          'waiting': 229,
#          'tish': 1,
#          'get': 2257,
#          'drive': 115,
#          'mom': 454,
#          'crv': 1,
#          'duckie': 2,
#          'first': 452,
#          'time': 2036,
#          'yupstill': 1,
#          'packed': 22,
#          'urobsession': 1,
#          'gon': 435,
#          'na': 738,
#          '80': 20,
#          'water': 89,
#          'prob': 27,
#          'cold': 249,
#          'heck': 21,
#          'boyfriend': 73,
#          'better': 626,
#          'mine': 189,
#          'hell': 143,
#          'smackdown': 1,
#          'lot': 487,
#          'boring': 117,
#          'maria': 9,
#          'still': 1306,
#          'little': 1060,
#          'shitty': 77,
#          'type': 66,
#          'guess': 341,
#          'thats': 635,
#          'bought': 78,
#          'black': 88,
#          'nail': 33,
#          'varnish': 1,
#          'co': 65,
#          'rebellious': 46,
#          'alone': 268,
#          'fix': 57,
#          'im': 5420,
#          'cry': 229,
#          'inanimate': 3,
#          'eye': 217,
#          'forgot': 118,
#          'passport': 4,
#          'realize': 66,
#          'stomach': 77,
#          'funny': 194,
#          'went': 319,
#          'washroom': 1,
#          'understand': 154,
#          'actually': 373,
#          'sick': 335,
#          'longg': 2,
#          'fun': 484,
#          'senior': 21,
#          'walk': 124,
#          'finally': 256,
#          'givemestrength': 1,
#          'ha': 118,
#          'check': 175,
#          'high': 136,
#          'score': 21,
#          'today': 1337,
#          'currently': 53,
#          'no1': 5,
#          'slot': 5,
#          '306000': 1,
#          'nassrenj': 1,
#          'miss': 776,
#          'guy': 451,
#          'b': 123,
#          'bk': 10,
#          'til': 87,
#          'august': 16,
#          'sumtime': 2,
#          'come': 707,
#          'anytime': 23,
#          'b4': 25,
#          '4': 249,
#          'sure': 512,
#          'let': 456,
#          'kno': 26,
#          'meant': 73,
#          'inhibited': 30,
#          'prohibited': 1,
#          'plead': 2,
#          'temporary': 8,
#          'insanity': 5,
#          'agreeing': 4,
#          'metric': 1,
#          'century': 12,
#          'cycling': 11,
#          'event': 74,
#          'tomorrow': 520,
#          'sad': 709,
#          'someone': 501,
#          'leaving': 119,
#          'body': 162,
#          'atypical': 1,
#          'ballet': 5,
#          'rain': 183,
#          'plain': 19,
#          'cloudy': 21,
#          'ignore': 344,
#          'chocoshabi': 1,
#          'going': 1565,
#          'ask': 145,
#          'waldi': 1,
#          'new': 888,
#          'keyword': 2,
#          'jojouk55': 1,
#          'good': 1767,
#          'saw': 232,
#          'shooting': 19,
#          'star': 161,
#          'made': 555,
#          'wish': 632,
#          'two': 330,
#          'many': 375,
#          'usually': 103,
#          'probably': 216,
#          'fact': 165,
#          'vm': 1,
#          'entertained': 31,
#          'love': 1705,
#          'character': 83,
#          'focus': 51,
#          'sorry': 628,
#          'upset': 111,
#          'loss': 69,
#          'material': 15,
#          'possession': 8,
#          'loved': 220,
#          'providing': 7,
#          'girl': 428,
#          'could': 895,
#          'something': 750,
#          'worthwhile': 50,
#          'natural': 15,
#          'breastfeeding': 2,
#          'tropigalia': 1,
#          'stink': 12,
#          'birthday': 154,
#          'bra': 7,
#          'youre': 391,
#          'anyhow': 4,
#          'spite': 9,
#          'home': 931,
#          'enjoying': 64,
#          'rest': 151,
#          'azongo': 1,
#          'smokefest': 1,
#          'woot': 7,
#          'mmot': 2,
#          'morganleigh321': 1,
#          'steveserrano': 1,
#          'adoreeeee': 1,
#          'matt': 18,
#          'nathanson': 1,
#          'jealous': 109,
#          'slightly': 114,
#          'envious': 34,
#          'julian': 3,
#          'young': 94,
#          'onesquotlook': 1,
#          'foundquotquotbreakfastquot': 1,
#          'leamcfly17': 1,
#          'help': 492,
#          'yet': 399,
#          'please': 296,
#          '34': 7,
#          'project': 92,
#          'car': 247,
#          '1': 172,
#          'simultaneously': 6,
#          'superior': 49,
#          'inferior': 4,
#          'writer': 34,
#          'take': 525,
#          'thing': 1182,
#          'said': 392,
#          'hesitant': 59,
#          'leave': 253,
#          'seriously': 101,
#          'bored': 182,
#          'tired': 379,
#          'enough': 365,
#          'sleep': 520,
#          'entered': 16,
#          'temple': 11,
#          'vaguely': 9,
#          'mrcrisis': 1,
#          'scared': 128,
#          'mskatrina25': 1,
#          'lmao': 70,
#          'pls': 15,
#          'tell': 361,
#          'migraine': 20,
#          'siphotwit': 1,
#          'impatient': 46,
#          'sinned': 1,
#          'strawberry': 16,
#          'milk': 27,
#          'sugar': 31,
#          'amazing': 289,
#          'tonight': 505,
#          'need': 1100,
#          'old': 338,
#          'pip': 3,
#          'constantly': 45,
#          'stage': 34,
#          'rather': 233,
#          'disruptive': 1,
#          'sometimes': 281,
#          'reacted': 6,
#          'along': 85,
#          'moved': 50,
#          'position': 28,
#          'dramatic': 6,
#          'scene': 34,
#          'left': 449,
#          'awkward': 76,
#          'dinner': 137,
#          'shower': 88,
#          'timethen': 1,
#          'revision': 37,
#          '5': 158,
#          'myinkyfingersau': 1,
#          'sleepy': 40,
#          'late': 164,
#          'fail': 90,
#          'unnamed': 1,
#          'area': 64,
#          'criticised': 1,
#          'appeared': 10,
#          'industrial': 3,
#          'dereliction': 1,
#          'downcast': 10,
#          'peopl': 1,
#          'play': 191,
#          'maybe': 332,
#          'heart': 245,
#          'blessed': 135,
#          'given': 76,
#          'chance': 105,
#          'delete': 10,
#          'really': 1855,
#          'important': 133,
#          'restrict': 1,
#          'access': 27,
#          'comment': 122,
#          'post': 229,
#          'crazy': 113,
#          'morning': 638,
#          '1030': 7,
#          'angry': 159,
#          'disillusioned': 32,
#          'brad': 9,
#          'olympic': 5,
#          'village': 16,
#          'watching': 366,
#          'season': 95,
#          '30': 50,
#          'rack': 4,
#          'adult': 28,
#          'hood': 8,
#          'battery': 24,
#          'low': 122,
#          'boooooooo': 3,
#          'palm': 14,
#          'spring': 30,
#          'ca': 21,
#          'httplooptus2sljbwt': 1,
#          'nickcarter': 14,
#          'ah': 80,
#          'nick': 27,
#          'youï¿½ve': 1,
#          'set': 134,
#          'vid': 24,
#          'private': 32,
#          'everyone': 360,
#          '2': 641,
#          'see': 1144,
#          'mistake': 44,
#          'another': 364,
#          'night': 852,
#          'scored': 2,
#          'mojito': 2,
#          'bless': 37,
#          'supportive': 52,
#          'family': 332,
#          'appreciate': 60,
#          'eating': 151,
#          'cadburys': 1,
#          'dairy': 3,
#          'giant': 28,
#          'chocolate': 72,
#          'button': 27,
#          'square': 14,
#          'dark': 72,
#          'satisfying': 3,
#          'lying': 24,
#          'dealseekingmom': 1,
#          'problem': 173,
#          'sweetthang15': 1,
#          'aww': 144,
#          'yeah': 404,
#          'hard': 326,
#          'mcrmuffin': 2,
#          'couldnt': 179,
#          'last': 807,
#          'cause': 216,
#          'fell': 74,
#          'asleep': 79,
#          'retard': 1,
#          'agh': 4,
#          'straight': 40,
#          'hair': 212,
#          'haha': 457,
#          'privileged': 42,
#          'watch': 292,
#          'beautiful': 164,
#          'dancer': 10,
#          'move': 160,
#          'call': 299,
#          'work': 1547,
#          'etniqminerals': 1,
#          'though': 730,
#          'admit': 90,
#          'seems': 162,
#          'le': 323,
#          'tempting': 7,
#          'complete': 46,
#          'package': 14,
#          'longest': 11,
#          'ever': 414,
#          'beach': 83,
#          'bound': 14,
#          'twitter': 543,
#          'rhysahughes': 1,
#          'httptinyurlcom6n4w5o': 1,
#          'prove': 15,
#          'tastenow': 1,
#          'dance': 63,
#          'radio': 49,
#          'feed': 38,
#          'strongly': 39,
#          'starve': 3,
#          'crappy': 74,
#          'processed': 1,
#          'dog': 141,
#          'food': 189,
#          'live': 281,
#          'forever': 60,
#          'vasilly': 2,
#          'thanks': 585,
#          'self': 133,
#          'quotmy': 6,
#          'accountquot': 1,
#          'dig': 14,
#          'deeper': 10,
#          'fannyaddams': 1,
#          'aw': 74,
#          'named': 16,
#          'sweet': 246,
#          'hear': 258,
#          'petey': 1,
#          'go': 1788,
#          'find': 477,
#          'posh': 5,
#          'rollerskate': 1,
#          'scooterwastaken': 1,
#          'think': 1249,
#          'hanger': 1,
#          'closet': 12,
#          'screw': 17,
#          'lem': 9,
#          'click': 20,
#          'ticket': 101,
#          'preetttty': 1,
#          'might': 306,
#          'vermillion': 1,
#          'lie': 75,
#          'opening': 30,
#          'tho': 126,
#          'loooong': 7,
#          'weekend': 441,
#          'inlawing': 1,
#          'browsing': 6,
#          'nd': 30,
#          'barca': 2,
#          'win': 104,
#          'da': 49,
#          'champ': 5,
#          'league': 8,
#          'watched': 96,
#          'bgt': 61,
#          'catch': 88,
#          'holly': 20,
#          'always': 609,
#          'jay': 27,
#          'welcomed': 48,
#          'confidence': 22,
#          'belong': 22,
#          'taylorswift13': 32,
#          'paramore': 6,
#          'welcome': 131,
#          'cheer': 49,
#          'tweet': 280,
#          'tink': 6,
#          'write': 204,
#          'word': 237,
#          'baby': 266,
#          'kick': 52,
#          'within': 68,
#          'memory': 72,
#          'refreshed': 12,
#          'would': 1156,
#          'anything': 392,
#          'boy': 213,
#          'baffled': 3,
#          'hurt': 385,
#          'assaulted': 24,
#          'unsafe': 2,
#          'ruimoura': 2,
#          'dude': 94,
#          'least': 264,
#          'rotate': 1,
#          'motherfucker': 1,
#          'grateful': 50,
#          'normally': 27,
#          'health': 50,
#          'title': 38,
#          'mimm': 1,
#          'fall': 98,
#          'inspired': 89,
#          'href': 166,
#          'http': 205,
#          'thislifeissparkling': 1,
#          'frustrated': 105,
#          'anymore': 178,
#          'fierce': 4,
#          'medium': 41,
#          'campaign': 6,
#          'egypt': 1,
#          'attack': 30,
#          'track': 45,
#          'limited': 16,
#          'able': 272,
#          'sync': 7,
#          'm': 24,
#          'exchange': 14,
#          'account': 78,
#          'iphone': 92,
#          'outlook': 8,
#          'lame': 88,
#          'robyn': 3,
#          'leant': 1,
#          'door': 74,
#          'office': 133,
#          'experiencing': 20,
#          'familiar': 19,
#          'surge': 6,
#          'deep': 82,
#          'annoya': 5,
#          'technicoloring': 1,
#          '1720': 1,
#          'except': 86,
#          'omg': 182,
#          'amy': 12,
#          'bb': 23,
#          'give': 326,
#          'loaner': 2,
#          'laptop': 71,
#          'may': 373,
#          'month': 274,
#          'abruptly': 1,
#          'reminded': 18,
#          'agitated': 117,
#          'la': 98,
#          'regretful': 47,
#          'bearablescents': 1,
#          'sitewarming': 1,
#          'party': 182,
#          'wellif': 1,
#          'sigjeans': 7,
#          'rosie': 3,
#          'vet': 17,
#          'routine': 21,
#          'shot': 61,
#          'bordatella': 1,
#          'vile': 7,
#          'brooding': 1,
#          'gnawing': 3,
#          'spirit': 51,
#          'irkengir': 1,
#          'result': 59,
#          'salary': 4,
#          'decrease': 2,
#          'trip': 125,
#          'great': 572,
#          'belive': 7,
#          'summer': 182,
#          'ignored': 63,
#          'message': 109,
#          'apology': 14,
#          'remorseful': 31,
#          'treated': 25,
#          'jonkragel': 1,
#          'ooooo': 6,
#          'playing': 141,
#          'around': 470,
#          'booksmovie': 1,
#          'trailer': 24,
#          'whn': 5,
#          'writing': 180,
#          'course': 124,
#          'gooooooooood': 2,
#          'release': 36,
#          'date': 78,
#          'zwaloo': 1,
#          'tried': 161,
#          'wayneliew': 1,
#          'cautious': 4,
#          'unmake': 65,
#          'pretty': 616,
#          'add': 84,
#          'working': 382,
#          'create': 31,
#          'nice': 410,
#          'community': 51,
#          'page': 96,
#          'connect': 20,
#          'easily': 45,
#          'approaching': 6,
#          'camabigail': 1,
#          'yes': 324,
#          'maam': 3,
#          'switch': 16,
#          'inspirational': 3,
#          'side': 126,
#          'lunchsubway': 1,
#          'eat': 195,
#          'freshnow': 1,
#          'ta': 172,
#          'started': 263,
#          'cranky': 58,
#          'grumpy': 50,
#          'ultimately': 10,
#          'ordinary': 10,
#          'facebook': 98,
#          'flash': 18,
#          'cousin': 37,
#          'west': 20,
#          'meath': 1,
#          'suddenly': 66,
#          'pinging': 2,
#          'bad': 668,
#          'joke': 38,
#          'naughty': 54,
#          'story': 175,
#          'rudolph': 1,
#          'valentino': 2,
#          'performing': 11,
#          'unspeakable': 1,
#          'act': 70,
#          'forth': 13,
#          'google': 65,
#          'flower': 46,
#          'logo': 8,
#          'httpwwwgooglecoin': 1,
#          'anger': 59,
#          'trusting': 43,
#          'letting': 41,
#          'treat': 47,
#          'miligosa': 1,
#          'tend': 33,
#          'fast': 76,
#          'phone': 310,
#          'hate': 554,
#          'anxiety': 32,
#          'crap': 90,
#          'cure': 13,
#          'present': 60,
#          'photo': 135,
#          'remember': 257,
#          'cute': 202,
#          'killer': 20,
#          'jonathan': 10,
#          'ross': 9,
#          'completely': 150,
#          'epitomised': 1,
#          'fangirl': 2,
#          'wow': 189,
#          'reading': 156,
#          'dublin': 13,
#          'llc1983': 1,
#          'genuineamy': 2,
#          '90': 15,
#          'btw': 80,
#          'name': 161,
#          'mix': 31,
#          'quotdamn': 2,
#          'man': 328,
#          'save': 70,
#          '90squot': 1,
#          'hahaha': 94,
#          'betrayed': 25,
#          'never': 625,
#          'begin': 66,
#          'benway08': 1,
#          'mmm': 29,
#          'nothing': 364,
#          'lucky': 143,
#          'friend': 775,
#          'breedimetria': 2,
#          'third': 33,
#          'foreign': 11,
#          'excited': 253,
#          'long': 463,
#          'satisfied': 71,
#          'pleased': 73,
#          'getting': 611,
#          'mark': 52,
#          'exam': 163,
#          'praise': 15,
#          'teacher': 62,
#          'performance': 32,
#          'hated': 123,
#          'listen': 96,
#          'tape': 13,
#          'mood': 107,
#          'done': 357,
#          'vmware': 2,
#          'fusion': 7,
#          'slower': 11,
#          'ajm1030': 1,
#          'movie': 332,
#          'awesome': 258,
#          'reload': 3,
#          'pistol': 3,
#          'agent': 7,
#          '0': 20,
#          'gambit': 2,
#          'enjoyed': 48,
#          'stupid': 256,
#          'losing': 56,
#          'pool': 47,
#          'table': 37,
#          'dnkanais': 1,
#          'reeeally': 4,
#          'interesting': 83,
#          'bike': 61,
#          '10': 88,
#          'company': 81,
#          'follower': 146,
#          'download': 36,
#          'amused': 47,
#          'jonasbrothers': 30,
#          'episode': 83,
#          'amazingi': 1,
#          'cried': 47,
#          'video': 149,
#          'soooooo': 11,
#          'aright': 1,
#          'fam': 30,
#          'ima': 31,
#          'outties': 1,
#          'try': 346,
#          'n': 164,
#          'horrible': 121,
#          'pain': 222,
#          'stevehealy': 2,
#          'poor': 184,
#          'must': 273,
#          'booked': 18,
#          'realised': 31,
#          'pat': 8,
#          'kennys': 2,
#          'gutted': 37,
#          'chrisdaughtry': 2,
#          'college': 69,
#          'town': 79,
#          'eau': 1,
#          'claire': 3,
#          'wi': 8,
#          'youd': 33,
#          'ton': 41,
#          'turn': 144,
#          'shes': 193,
#          'missing': 168,
#          'critical': 6,
#          'mass': 17,
#          'rainstormiee': 1,
#          'thank': 277,
#          'amberndragt': 1,
#          'isnt': 218,
#          'meanmillies': 1,
#          'boo': 91,
#          'customcreation': 1,
#          'drank': 17,
#          'away': 454,
#          'bank': 93,
#          'holiday': 135,
#          'net': 25,
#          'mum': 152,
#          'littlepiddle1': 1,
#          'hey': 316,
#          'chiclit': 1,
#          'whats': 170,
#          'happening': 48,
#          'promote': 4,
#          'business': 68,
#          'saturday': 96,
#          'fever': 39,
#          'stay': 172,
#          'lastnite': 1,
#          'whole': 251,
#          'resolved': 41,
#          'afraid': 139,
#          'thinking': 252,
#          'reassured': 43,
#          'mean': 349,
#          'tweeter': 13,
#          'beetle': 2,
#          'search': 28,
#          'bring': 86,
#          'zilch': 1,
#          'bar': 52,
#          'peep': 28,
#          'appear': 19,
#          'manthigh81': 1,
#          'didnt': 771,
#          'nashville': 5,
#          'offer': 56,
#          'pc': 30,
#          'authority': 9,
#          'review': 45,
#          'tivo': 2,
#          'vod': 1,
#          'service': 64,
#          'httpbitlyps7y2': 1,
#          'loving': 139,
#          'making': 308,
#          'missed': 272,
#          'autumn': 7,
#          'colour': 24,
#          'ack': 6,
#          'forward': 168,
#          'coldplay': 5,
#          'song': 294,
#          'skin': 62,
#          'burning': 16,
#          'lunch': 148,
#          'clock': 17,
#          'damn': 277,
#          'hour': 484,
#          '20': 40,
#          'beginning': 58,
#          'opportunity': 50,
#          'child': 209,
#          'half': 158,
#          'lovely': 173,
#          'sat': 90,
#          'okay': 143,
#          'later': 218,
#          'quinn': 2,
#          'end': 305,
#          'hurting': 28,
#          'barney': 1,
#          'ted': 3,
#          'robin': 12,
#          'storyline': 2,
#          'jofarnold': 2,
#          'aha': 15,
#          'meaning': 19,
#          'cool': 304,
#          'musiicbox': 1,
#          'shame': 69,
#          'whatsoever': 7,
#          'longing': 52,
#          'iron': 14,
#          'local': 47,
#          'cineworld': 1,
#          'considerate': 18,
#          'others': 176,
#          'oops': 21,
#          'boston': 15,
#          'red': 89,
#          'sox': 5,
#          'instead': 149,
#          'sux': 21,
#          'tampa': 8,
#          'bay': 13,
#          'ray': 13,
#          'devil': 10,
#          'previous': 20,
#          'habit': 14,
#          'krystynchong': 4,
#          'buddy': 25,
#          'noticed': 43,
#          'struggle': 36,
#          'depressed': 141,
#          'pickassoreborn': 1,
#          'lover': 24,
#          'listener': 4,
#          'cuddle': 17,
#          'bit': 743,
#          'listless': 47,
#          'pro': 18,
#          'hiding': 24,
#          'true': 112,
#          'crack': 22,
#          'coming': 272,
#          'repair': 10,
#          'throw': 57,
#          'supporting': 101,
#          'rock': 88,
#          'starting': 177,
#          'becoming': 45,
#          'bitter': 60,
#          'travispoling': 1,
#          'setting': 28,
#          'link': 103,
#          'public': 64,
#          'timeline': 4,
#          'bottom': 27,
#          'luzyartillero': 1,
#          'sana': 3,
#          'selling': 18,
#          'full': 168,
#          'version': 62,
#          'quotcoding': 1,
#          'workshop': 5,
#          'recovery': 8,
#          'wizardquot': 1,
#          'cd': 34,
#          'demo': 10,
#          'mode': 23,
#          'lang': 8,
#          'eh': 34,
#          'robfindlay': 1,
#          'httptinyurlcomd4l3oe': 1,
#          'desktop': 19,
#          'wallpaper': 10,
#          'inside': 148,
#          'monitor': 9,
#          'bumbed': 2,
#          'delicate': 39,
#          'gentle': 50,
#          'wth': 8,
#          'ayawan': 2,
#          'pressured': 57,
#          'desk': 28,
#          'due': 91,
#          'pile': 11,
#          'task': 31,
#          'often': 185,
#          'pack': 28,
#          'quiet': 50,
#          'corner': 27,
#          'bedroom': 13,
#          'living': 111,
#          'room': 196,
#          'kitchen': 38,
#          'honoured': 49,
#          'prize': 15,
#          'photography': 18,
#          'exhibition': 6,
#          'recently': 49,
#          'asked': 102,
#          'getty': 1,
#          'image': 40,
#          'quite': 340,
#          'number': 92,
#          'part': 255,
#          'world': 368,
#          'renowned': 3,
#          'collection': 26,
#          'photographic': 1,
#          'peace': 67,
#          'packing': 34,
#          'saying': 156,
#          'bye': 56,
#          'dealing': 21,
#          'overwhelming': 11,
#          'displacement': 1,
#          'sunny': 61,
#          'subbasement': 1,
#          'raining': 80,
#          'premature': 3,
#          'devastated': 76,
#          'adriana': 1,
#          'cozy': 4,
#          'hot': 255,
#          'cocoa': 2,
#          ...})

# %%
num_words = len(counter)
max_length = 20

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(train_dataset.Text)
# Out:
# 2022-05-19 12:20:25.879080: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-19 12:20:25.879098: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'feel': 1,
#  'feeling': 2,
#  'im': 3,
#  'happy': 4,
#  'like': 5,
#  'day': 6,
#  'get': 7,
#  'time': 8,
#  'really': 9,
#  'go': 10,
#  'good': 11,
#  'one': 12,
#  'love': 13,
#  'know': 14,
#  'going': 15,
#  'work': 16,
#  'want': 17,
#  'got': 18,
#  'make': 19,
#  'cant': 20,
#  'back': 21,
#  'today': 22,
#  'u': 23,
#  'still': 24,
#  'think': 25,
#  'thing': 26,
#  'would': 27,
#  'see': 28,
#  'need': 29,
#  'much': 30,
#  'little': 31,
#  'people': 32,
#  'well': 33,
#  'ive': 34,
#  'home': 35,
#  'even': 36,
#  'way': 37,
#  'could': 38,
#  'new': 39,
#  'life': 40,
#  'lol': 41,
#  'mother': 42,
#  'right': 43,
#  'night': 44,
#  'last': 45,
#  'say': 46,
#  'miss': 47,
#  'friend': 48,
#  'didnt': 49,
#  'something': 50,
#  'amp': 51,
#  'bit': 52,
#  'na': 53,
#  'though': 54,
#  'week': 55,
#  'oh': 56,
#  'sad': 57,
#  'come': 58,
#  'ill': 59,
#  'look': 60,
#  'hope': 61,
#  'bad': 62,
#  '2': 63,
#  'morning': 64,
#  'thats': 65,
#  'wish': 66,
#  'year': 67,
#  'sorry': 68,
#  'better': 69,
#  'never': 70,
#  'pretty': 71,
#  'getting': 72,
#  'always': 73,
#  'thanks': 74,
#  'great': 75,
#  'made': 76,
#  'hate': 77,
#  'twitter': 78,
#  'take': 79,
#  'also': 80,
#  'thought': 81,
#  'tomorrow': 82,
#  'sleep': 83,
#  'sure': 84,
#  'tonight': 85,
#  'someone': 86,
#  'help': 87,
#  'lot': 88,
#  'fun': 89,
#  'hour': 90,
#  'find': 91,
#  'school': 92,
#  'around': 93,
#  'next': 94,
#  'long': 95,
#  'away': 96,
#  'haha': 97,
#  'let': 98,
#  'mom': 99,
#  'first': 100,
#  'guy': 101,
#  'left': 102,
#  'weekend': 103,
#  'gon': 104,
#  'trying': 105,
#  'keep': 106,
#  'girl': 107,
#  'bed': 108,
#  'ever': 109,
#  'show': 110,
#  'nice': 111,
#  'yeah': 112,
#  'already': 113,
#  'yet': 114,
#  'said': 115,
#  'anything': 116,
#  'youre': 117,
#  'hurt': 118,
#  'working': 119,
#  'tired': 120,
#  'many': 121,
#  'actually': 122,
#  'may': 123,
#  'soon': 124,
#  'every': 125,
#  'world': 126,
#  'without': 127,
#  'watching': 128,
#  'enough': 129,
#  'best': 130,
#  'another': 131,
#  'nothing': 132,
#  'felt': 133,
#  'everything': 134,
#  'tell': 135,
#  'everyone': 136,
#  'done': 137,
#  'start': 138,
#  'ok': 139,
#  'mean': 140,
#  'try': 141,
#  'ignore': 142,
#  'guess': 143,
#  'quite': 144,
#  'wait': 145,
#  'old': 146,
#  'sick': 147,
#  'suck': 148,
#  'maybe': 149,
#  'family': 150,
#  'movie': 151,
#  'since': 152,
#  'kind': 153,
#  'two': 154,
#  'man': 155,
#  'hard': 156,
#  'give': 157,
#  'yes': 158,
#  'doesnt': 159,
#  'le': 160,
#  'god': 161,
#  'looking': 162,
#  'went': 163,
#  'lost': 164,
#  'hey': 165,
#  'read': 166,
#  'phone': 167,
#  'house': 168,
#  'making': 169,
#  'might': 170,
#  'end': 171,
#  'cool': 172,
#  'place': 173,
#  'person': 174,
#  'put': 175,
#  'call': 176,
#  'please': 177,
#  'job': 178,
#  'song': 179,
#  'watch': 180,
#  'id': 181,
#  'head': 182,
#  'amazing': 183,
#  'wan': 184,
#  'talk': 185,
#  'sometimes': 186,
#  'live': 187,
#  'tweet': 188,
#  'book': 189,
#  'thank': 190,
#  'damn': 191,
#  'face': 192,
#  'found': 193,
#  'month': 194,
#  'must': 195,
#  'able': 196,
#  'missed': 197,
#  'coming': 198,
#  'anyone': 199,
#  'alone': 200,
#  'baby': 201,
#  'kid': 202,
#  'least': 203,
#  'big': 204,
#  'started': 205,
#  'ur': 206,
#  'almost': 207,
#  'hear': 208,
#  'awesome': 209,
#  'remember': 210,
#  'moment': 211,
#  'finally': 212,
#  'stupid': 213,
#  'part': 214,
#  'hot': 215,
#  'forget': 216,
#  'wanted': 217,
#  'stop': 218,
#  'leave': 219,
#  'excited': 220,
#  'thinking': 221,
#  'whole': 222,
#  'havent': 223,
#  'cold': 224,
#  '4': 225,
#  'car': 226,
#  'sweet': 227,
#  'ready': 228,
#  'free': 229,
#  'heart': 230,
#  'blog': 231,
#  'friday': 232,
#  'differ': 233,
#  'word': 234,
#  '3': 235,
#  'stuff': 236,
#  'rather': 237,
#  'saw': 238,
#  'use': 239,
#  'waiting': 240,
#  'cry': 241,
#  'post': 242,
#  'glad': 243,
#  'class': 244,
#  'totally': 245,
#  'believe': 246,
#  'else': 247,
#  'far': 248,
#  'pain': 249,
#  'he': 250,
#  'x': 251,
#  'loved': 252,
#  'sound': 253,
#  'isnt': 254,
#  'later': 255,
#  'eye': 256,
#  'real': 257,
#  'probably': 258,
#  'cause': 259,
#  'wasnt': 260,
#  'boy': 261,
#  'hair': 262,
#  'follow': 263,
#  'game': 264,
#  'idea': 265,
#  'monday': 266,
#  'child': 267,
#  'gone': 268,
#  'http': 269,
#  'write': 270,
#  'reason': 271,
#  'hand': 272,
#  'cute': 273,
#  'change': 274,
#  'told': 275,
#  'music': 276,
#  'money': 277,
#  'point': 278,
#  'room': 279,
#  'came': 280,
#  'eat': 281,
#  'wrong': 282,
#  'weather': 283,
#  'early': 284,
#  'picture': 285,
#  'funny': 286,
#  'shes': 287,
#  'yesterday': 288,
#  'used': 289,
#  'play': 290,
#  'woman': 291,
#  'taking': 292,
#  'mine': 293,
#  'food': 294,
#  'wow': 295,
#  'run': 296,
#  'sun': 297,
#  'weird': 298,
#  'often': 299,
#  'mind': 300,
#  'poor': 301,
#  'woke': 302,
#  'ugh': 303,
#  'rain': 304,
#  'bored': 305,
#  'omg': 306,
#  'party': 307,
#  'summer': 308,
#  'pic': 309,
#  'minute': 310,
#  'writing': 311,
#  'enjoy': 312,
#  'couldnt': 313,
#  'anymore': 314,
#  'kinda': 315,
#  'there': 316,
#  'starting': 317,
#  'care': 318,
#  'ya': 319,
#  'others': 320,
#  'lt3': 321,
#  'check': 322,
#  'story': 323,
#  'ago': 324,
#  'problem': 325,
#  'lovely': 326,
#  '1': 327,
#  'ta': 328,
#  'stay': 329,
#  'whats': 330,
#  'missing': 331,
#  'forward': 332,
#  'full': 333,
#  'href': 334,
#  'took': 335,
#  'fact': 336,
#  'till': 337,
#  'late': 338,
#  'beautiful': 339,
#  'n': 340,
#  'plan': 341,
#  'sitting': 342,
#  'exam': 343,
#  'body': 344,
#  'seems': 345,
#  'star': 346,
#  'tried': 347,
#  'name': 348,
#  'listening': 349,
#  'move': 350,
#  'shit': 351,
#  'stressed': 352,
#  'angry': 353,
#  'wonderful': 354,
#  'yay': 355,
#  'hi': 356,
#  'super': 357,
#  '5': 358,
#  'half': 359,
#  'outside': 360,
#  'past': 361,
#  'reading': 362,
#  'saying': 363,
#  'close': 364,
#  'strange': 365,
#  'understand': 366,
#  'birthday': 367,
#  'fine': 368,
#  'mum': 369,
#  'rest': 370,
#  'eating': 371,
#  'completely': 372,
#  'fan': 373,
#  'especially': 374,
#  'video': 375,
#  'instead': 376,
#  'talking': 377,
#  'lunch': 378,
#  'inside': 379,
#  'mad': 380,
#  'share': 381,
#  'seen': 382,
#  'broke': 383,
#  'follower': 384,
#  'ask': 385,
#  'sunday': 386,
#  'finished': 387,
#  'aww': 388,
#  'turn': 389,
#  'hell': 390,
#  'lucky': 391,
#  'okay': 392,
#  'parent': 393,
#  'headache': 394,
#  'knew': 395,
#  'dog': 396,
#  'playing': 397,
#  'depressed': 398,
#  'dream': 399,
#  'special': 400,
#  'either': 401,
#  'perfect': 402,
#  'buy': 403,
#  'afraid': 404,
#  'loving': 405,
#  'break': 406,
#  'overwhelmed': 407,
#  'dinner': 408,
#  'running': 409,
#  'high': 410,
#  'meet': 411,
#  'wake': 412,
#  'second': 413,
#  'anxious': 414,
#  'blessed': 415,
#  'photo': 416,
#  'holiday': 417,
#  'news': 418,
#  'looked': 419,
#  'sense': 420,
#  'set': 421,
#  'stuck': 422,
#  'important': 423,
#  'self': 424,
#  'office': 425,
#  'together': 426,
#  'happened': 427,
#  'accepted': 428,
#  'hit': 429,
#  'seeing': 430,
#  'called': 431,
#  'welcome': 432,
#  'dad': 433,
#  'become': 434,
#  'scared': 435,
#  'open': 436,
#  'experience': 437,
#  'luck': 438,
#  'computer': 439,
#  'tho': 440,
#  'side': 441,
#  'happen': 442,
#  'couple': 443,
#  'theyre': 444,
#  'trip': 445,
#  'spent': 446,
#  'walk': 447,
#  'course': 448,
#  'tv': 449,
#  'wonder': 450,
#  'b': 451,
#  'hated': 452,
#  'heard': 453,
#  'coffee': 454,
#  'sort': 455,
#  'matter': 456,
#  'comment': 457,
#  'low': 458,
#  'following': 459,
#  'seem': 460,
#  'hug': 461,
#  'w': 462,
#  'busy': 463,
#  'horrible': 464,
#  'lately': 465,
#  'leaving': 466,
#  'fucking': 467,
#  'forgot': 468,
#  'ha': 469,
#  'lonely': 470,
#  'boring': 471,
#  'agitated': 472,
#  'wear': 473,
#  'nervous': 474,
#  'liked': 475,
#  'helpless': 476,
#  'different': 477,
#  'longer': 478,
#  'towards': 479,
#  'drive': 480,
#  'card': 481,
#  'r': 482,
#  'internet': 483,
#  'disappointed': 484,
#  'slightly': 485,
#  'online': 486,
#  'p': 487,
#  'supposed': 488,
#  'drink': 489,
#  'crazy': 490,
#  'safe': 491,
#  'true': 492,
#  'hopefully': 493,
#  'brother': 494,
#  'question': 495,
#  'proud': 496,
#  'upset': 497,
#  'living': 498,
#  'situation': 499,
#  'passionate': 500,
#  'guilty': 501,
#  'email': 502,
#  'xx': 503,
#  'jealous': 504,
#  'message': 505,
#  'list': 506,
#  'site': 507,
#  'future': 508,
#  'absolutely': 509,
#  'strong': 510,
#  'small': 511,
#  'spend': 512,
#  'mood': 513,
#  'using': 514,
#  'foot': 515,
#  'fuck': 516,
#  'lady': 517,
#  'moving': 518,
#  'cut': 519,
#  'three': 520,
#  'chance': 521,
#  'frustrated': 522,
#  'truly': 523,
#  'smile': 524,
#  'dead': 525,
#  'sooo': 526,
#  'wouldnt': 527,
#  'win': 528,
#  'awww': 529,
#  'decided': 530,
#  'usually': 531,
#  'link': 532,
#  'exhausted': 533,
#  'miserable': 534,
#  'asked': 535,
#  'city': 536,
#  'awake': 537,
#  'extremely': 538,
#  'unhappy': 539,
#  'seriously': 540,
#  'ticket': 541,
#  'supporting': 542,
#  'needed': 543,
#  'cat': 544,
#  'front': 545,
#  'short': 546,
#  'evening': 547,
#  'gave': 548,
#  'thankful': 549,
#  'top': 550,
#  'reply': 551,
#  'awful': 552,
#  'comfortable': 553,
#  'sister': 554,
#  'sit': 555,
#  'definitely': 556,
#  'send': 557,
#  'anyway': 558,
#  'fall': 559,
#  'la': 560,
#  'facebook': 561,
#  'issue': 562,
#  'learn': 563,
#  'update': 564,
#  'meeting': 565,
#  'watched': 566,
#  'page': 567,
#  'listen': 568,
#  'saturday': 569,
#  'generous': 570,
#  'giving': 571,
#  'mommy': 572,
#  'final': 573,
#  'finger': 574,
#  'season': 575,
#  'whatever': 576,
#  'particularly': 577,
#  'confused': 578,
#  'shopping': 579,
#  'young': 580,
#  'dude': 581,
#  'hahaha': 582,
#  'emotional': 583,
#  'cuz': 584,
#  'line': 585,
#  'hoping': 586,
#  'bank': 587,
#  'hello': 588,
#  'voice': 589,
#  'arm': 590,
#  'terrible': 591,
#  'vote': 592,
#  'project': 593,
#  'iphone': 594,
#  'number': 595,
#  'realized': 596,
#  'behind': 597,
#  'answer': 598,
#  'goodnight': 599,
#  'boo': 600,
#  'due': 601,
#  'sleeping': 602,
#  'bothered': 603,
#  'relationship': 604,
#  'arent': 605,
#  'fail': 606,
#  'admit': 607,
#  'crap': 608,
#  'sat': 609,
#  'worse': 610,
#  'test': 611,
#  'soo': 612,
#  'water': 613,
#  'inspired': 614,
#  'red': 615,
#  'window': 616,
#  'surprised': 617,
#  'leg': 618,
#  'black': 619,
#  'shower': 620,
#  'catch': 621,
#  'lame': 622,
#  '10': 623,
#  'rock': 624,
#  'deal': 625,
#  'state': 626,
#  'husband': 627,
#  'wife': 628,
#  'til': 629,
#  'exactly': 630,
#  'offended': 631,
#  'confident': 632,
#  'empty': 633,
#  'except': 634,
#  'bring': 635,
#  'worth': 636,
#  'energy': 637,
#  'somehow': 638,
#  'along': 639,
#  'taken': 640,
#  'group': 641,
#  'team': 642,
#  'add': 643,
#  'finish': 644,
#  'positive': 645,
#  'control': 646,
#  'son': 647,
#  'gift': 648,
#  'support': 649,
#  'beloved': 650,
#  'character': 651,
#  'beach': 652,
#  'interesting': 653,
#  'episode': 654,
#  'warm': 655,
#  'pissed': 656,
#  'hang': 657,
#  'paper': 658,
#  'although': 659,
#  'died': 660,
#  'men': 661,
#  'somewhat': 662,
#  'deep': 663,
#  '6': 664,
#  'company': 665,
#  'single': 666,
#  'stand': 667,
#  'hungry': 668,
#  'clean': 669,
#  'amazed': 670,
#  'ashamed': 671,
#  'text': 672,
#  'ah': 673,
#  'btw': 674,
#  'raining': 675,
#  'touch': 676,
#  'popular': 677,
#  'however': 678,
#  'creative': 679,
#  'power': 680,
#  'mr': 681,
#  'content': 682,
#  'wishing': 683,
#  'tortured': 684,
#  'favorite': 685,
#  'fantastic': 686,
#  'ice': 687,
#  'lose': 688,
#  'asleep': 689,
#  'town': 690,
#  'etc': 691,
#  'age': 692,
#  'successful': 693,
#  'country': 694,
#  'useless': 695,
#  'light': 696,
#  'rude': 697,
#  'tea': 698,
#  'tear': 699,
#  'gorgeous': 700,
#  'whether': 701,
#  'pay': 702,
#  'bought': 703,
#  'account': 704,
#  'date': 705,
#  'breakfast': 706,
#  'sigh': 707,
#  'caring': 708,
#  'broken': 709,
#  'sore': 710,
#  'terrified': 711,
#  'shitty': 712,
#  'stomach': 713,
#  'driving': 714,
#  'annoyed': 715,
#  'concert': 716,
#  'huge': 717,
#  'film': 718,
#  'case': 719,
#  'space': 720,
#  'war': 721,
#  'awkward': 722,
#  'given': 723,
#  'fast': 724,
#  'devastated': 725,
#  'air': 726,
#  'met': 727,
#  'rich': 728,
#  'daughter': 729,
#  'lil': 730,
#  'joy': 731,
#  'embarrassed': 732,
#  'emotion': 733,
#  'lie': 734,
#  'piece': 735,
#  'began': 736,
#  'useful': 737,
#  'dumb': 738,
#  'certain': 739,
#  'resentful': 740,
#  'fucked': 741,
#  'hold': 742,
#  'afternoon': 743,
#  'bout': 744,
#  'event': 745,
#  'fell': 746,
#  'crappy': 747,
#  'aw': 748,
#  'door': 749,
#  'honestly': 750,
#  'gloomy': 751,
#  'youll': 752,
#  '8': 753,
#  'student': 754,
#  'trust': 755,
#  'impressed': 756,
#  'boyfriend': 757,
#  'meant': 758,
#  'pleased': 759,
#  'curious': 760,
#  'happens': 761,
#  'suppose': 762,
#  'weight': 763,
#  'youtube': 764,
#  'as': 765,
#  'brave': 766,
#  'throat': 767,
#  'knowing': 768,
#  'chocolate': 769,
#  'dark': 770,
#  'memory': 771,
#  'easy': 772,
#  'bus': 773,
#  'order': 774,
#  'heading': 775,
#  'nap': 776,
#  'ugly': 777,
#  'nt': 778,
#  'fear': 779,
#  'uncomfortable': 780,
#  'shoe': 781,
#  'pick': 782,
#  'laptop': 783,
#  'satisfied': 784,
#  'sign': 785,
#  'figure': 786,
#  'gt': 787,
#  'calm': 788,
#  'ipod': 789,
#  'delicious': 790,
#  'mile': 791,
#  'white': 792,
#  'trek': 793,
#  'irritable': 794,
#  'lmao': 795,
#  'act': 796,
#  'save': 797,
#  'irritated': 798,
#  'greedy': 799,
#  'c': 800,
#  'yea': 801,
#  'selfish': 802,
#  'cleaning': 803,
#  'hehe': 804,
#  'decision': 805,
#  'doctor': 806,
#  'loss': 807,
#  'college': 808,
#  'shame': 809,
#  'learning': 810,
#  'ate': 811,
#  'store': 812,
#  'worked': 813,
#  'study': 814,
#  'wondering': 815,
#  'continue': 816,
#  'style': 817,
#  'hopeless': 818,
#  'slow': 819,
#  'race': 820,
#  'church': 821,
#  'blue': 822,
#  'die': 823,
#  'sadly': 824,
#  'numb': 825,
#  'telling': 826,
#  'within': 827,
#  'business': 828,
#  'brain': 829,
#  'near': 830,
#  '7': 831,
#  'yall': 832,
#  'road': 833,
#  'frightened': 834,
#  'art': 835,
#  'lesson': 836,
#  'posted': 837,
#  'choice': 838,
#  'attention': 839,
#  'turned': 840,
#  'human': 841,
#  'earlier': 842,
#  'heartbroken': 843,
#  'soooo': 844,
#  'pathetic': 845,
#  'peace': 846,
#  'aching': 847,
#  'uk': 848,
#  'visit': 849,
#  'talented': 850,
#  'punished': 851,
#  'precious': 852,
#  'dull': 853,
#  'type': 854,
#  'realize': 855,
#  'suddenly': 856,
#  'begin': 857,
#  'quiet': 858,
#  'discouraged': 859,
#  'drinking': 860,
#  'apprehensive': 861,
#  'stopped': 862,
#  'dear': 863,
#  'train': 864,
#  'agree': 865,
#  'across': 866,
#  'worst': 867,
#  'load': 868,
#  'homesick': 869,
#  'vain': 870,
#  'co': 871,
#  'unmake': 872,
#  'google': 873,
#  'dress': 874,
#  'ride': 875,
#  'kill': 876,
#  'relaxed': 877,
#  'friendly': 878,
#  'vulnerable': 879,
#  'violent': 880,
#  'blank': 881,
#  'paranoid': 882,
#  'sympathetic': 883,
#  'fake': 884,
#  'simply': 885,
#  'perhaps': 886,
#  'lethargic': 887,
#  'isolated': 888,
#  'rejected': 889,
#  'divine': 890,
#  'enjoying': 891,
#  'area': 892,
#  'service': 893,
#  'public': 894,
#  'album': 895,
#  'em': 896,
#  'death': 897,
#  'english': 898,
#  'smart': 899,
#  'clothes': 900,
#  'whenever': 901,
#  'return': 902,
#  'worried': 903,
#  'smell': 904,
#  'productive': 905,
#  'rushed': 906,
#  'dance': 907,
#  'ignored': 908,
#  'wedding': 909,
#  'youve': 910,
#  'kiss': 911,
#  'step': 912,
#  'hopeful': 913,
#  'lack': 914,
#  'putting': 915,
#  'determined': 916,
#  'melancholy': 917,
#  'joyful': 918,
#  'disgusted': 919,
#  'possible': 920,
#  'valued': 921,
#  'london': 922,
#  'walking': 923,
#  'uncertain': 924,
#  'park': 925,
#  'band': 926,
#  'innocent': 927,
#  'teacher': 928,
#  'skin': 929,
#  'version': 930,
#  'pas': 931,
#  'mitchelmusso': 932,
#  'distracted': 933,
#  'imagine': 934,
#  'shaken': 935,
#  'father': 936,
#  'fair': 937,
#  'walked': 938,
#  'sincere': 939,
#  'insulted': 940,
#  'shy': 941,
#  'garden': 942,
#  'gym': 943,
#  'bgt': 944,
#  'shot': 945,
#  'bike': 946,
#  'sunny': 947,
#  'spending': 948,
#  'five': 949,
#  'extra': 950,
#  'effort': 951,
#  'fb': 952,
#  'played': 953,
#  'dangerous': 954,
#  'wanting': 955,
#  'cake': 956,
#  'sent': 957,
#  'lazy': 958,
#  'valuable': 959,
#  'club': 960,
#  'june': 961,
#  'worry': 962,
#  'appreciate': 963,
#  'forever': 964,
#  'present': 965,
#  'bitter': 966,
#  'threatened': 967,
#  'mention': 968,
#  'faithful': 969,
#  'middle': 970,
#  'aint': 971,
#  'christmas': 972,
#  'note': 973,
#  'level': 974,
#  'hesitant': 975,
#  'result': 976,
#  'anger': 977,
#  'somewhere': 978,
#  'xxx': 979,
#  'respected': 980,
#  'defeated': 981,
#  'insecure': 982,
#  'unfortunately': 983,
#  'studying': 984,
#  'normal': 985,
#  'cream': 986,
#  'fabulous': 987,
#  'unsure': 988,
#  'pleasant': 989,
#  'cranky': 990,
#  'beginning': 991,
#  'everyday': 992,
#  'allowed': 993,
#  'suffering': 994,
#  'shocked': 995,
#  'energetic': 996,
#  'wearing': 997,
#  'convinced': 998,
#  'goin': 999,
#  'clever': 1000,
#  ...}

# %%
train_sequences = tokenizer.texts_to_sequences(train_dataset.Text)

# %%
train_sequences[0]
# Out:
# [6362,
#  67,
#  1893,
#  55,
#  324,
#  43,
#  387,
#  189,
#  20,
#  246,
#  229,
#  1,
#  395,
#  1893,
#  711,
#  40,
#  127,
#  3163]

# %%
dataset.Text[0]
# Out:
# 'didnt feel humiliated'

# %%
from keras.preprocessing.sequence import pad_sequences
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding="post", truncating="post")

# %%
train_padded[0]
# Out:
# array([6362,   67, 1893,   55,  324,   43,  387,  189,   20,  246,  229,
#           1,  395, 1893,  711,   40,  127, 3163,    0,    0], dtype=int32)

# %%
train_padded.shape
# Out:
# (48505, 20)

# %%
test_sequences = tokenizer.texts_to_sequences(test_dataset.Text)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding="post", truncating="post")

# %%
train_dataset.Emotion.unique()
# Out:
# array(['fear', 'hate', 'neutral', 'worry', 'sadness', 'happy', 'surprise',
#        'enthusiasm', 'anger', 'fun', 'relief', 'love', 'boredom'],
#       dtype=object)

# %%
train_dataset.Emotion.replace(
    {"worry":0,
    "sadness":1,
    "surprise":2,
    "happy":3,
    "fun":4,
    "hate":5,
    "fear":6,
    "neutral":7,
    "relief":8,
    "anger":9,
    "love":10,
    "boredom":11,
    "enthusiasm":12}
)
# Out:
# 365      6
# 4953     5
# 30240    7
# 15830    0
# 15336    1
#         ..
# 5263     6
# 7595     9
# 17485    2
# 3176     0
# 33568    4
# Name: Emotion, Length: 48505, dtype: int64

# %%
print(train_dataset.Text[2])
print(train_sequences[2])
# Out:
# funeral ceremonygloomy friday
# [4, 42, 6, 42]

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
def decode(text):
    return " ".join([reverse_word_index.get(i, "?") for i in text])

# %%
print(f"Shape of train {train_padded.shape}")
print(f"Shape of test {test_padded.shape}")
# Out:
# Shape of train (48505, 20)
# Shape of test (12127, 20)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.initializers import Constant
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Flatten())
model.add(Embedding(num_words, 32, input_length=max_length))
model.add(LSTM(64, dropout=0.1))
model.add(Dense(13, activation="softmax"))

optimizer = Adam(learning_rate=3e-4)

model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
# Out:
# 2022-05-19 12:20:30.118108: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-19 12:20:30.118140: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-19 12:20:30.118157: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (subut0n-PC): /proc/driver/nvidia/version does not exist
# 2022-05-19 12:20:30.118871: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_padded.shape
# Out:
# (48505, 20)

# %%
model.build(input_shape=(48505, 20))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (48505, 20)               0
#
#  embedding (Embedding)       (48505, 20, 32)           1472992
#
#  lstm (LSTM)                 (48505, 64)               24832
#
#  dense (Dense)               (48505, 13)               845
#
# =================================================================
# Total params: 1,498,669
# Trainable params: 1,498,669
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_padded, train_dataset.Emotion, epochs=20, validation_data=(test_padded, test_dataset.Emotion))
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/subut0n/Documents/simplon/Emotion-app/Notebooks/preprocessing.ipynb Cell 56' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/subut0n/Documents/simplon/Emotion-app/Notebooks/preprocessing.ipynb#ch0000055?line=0'>1</a> history = model.fit(train_padded, train_dataset.Emotion, epochs=20, validation_data=(test_padded, test_dataset.Emotion))
#
# File ~/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File ~/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1144'>1145</a> except Exception as e:  # pylint:disable=broad-except
#    <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1145'>1146</a>   if hasattr(e, "ag_error_metadata"):
# -> <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1146'>1147</a>     raise e.ag_error_metadata.to_exception(e)
#    <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1147'>1148</a>   else:
#    <a href='file:///home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1148'>1149</a>     raise
#
# ValueError: in user code:
#
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/losses.py", line 1932, in binary_crossentropy
#         backend.binary_crossentropy(y_true, y_pred, from_logits=from_logits),
#     File "/home/subut0n/anaconda3/envs/ML_env/lib/python3.8/site-packages/keras/backend.py", line 5247, in binary_crossentropy
#         return tf.nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#
#     ValueError: `logits` and `labels` must have the same shape, received ((None, 13) vs (None, 1)).
